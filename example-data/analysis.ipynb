# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# $AMBERHOME/bin/process_mdout.perl FILENAME.out
heating_data_dir = './'
equil_data_dir = './'

# %%
! ls equil_data
# Out:
# summary.DENSITY   summary_avg.DENSITY	summary_rms.DENSITY
# summary.EKCMT	  summary_avg.EKCMT	summary_rms.EKCMT
# summary.EKTOT	  summary_avg.EKTOT	summary_rms.EKTOT
# summary.EPTOT	  summary_avg.EPTOT	summary_rms.EPTOT
# summary.ESCF	  summary_avg.ESCF	summary_rms.ESCF
# summary.ETOT	  summary_avg.ETOT	summary_rms.ETOT
# summary.PRES	  summary_avg.PRES	summary_rms.PRES
# summary.TEMP	  summary_avg.TEMP	summary_rms.TEMP
# summary.TSOLUTE   summary_avg.TSOLUTE	summary_rms.TSOLUTE
# summary.TSOLVENT  summary_avg.TSOLVENT	summary_rms.TSOLVENT
# summary.VOLUME	  summary_avg.VOLUME	summary_rms.VOLUME

# %%
KE_x, KE_y = np.loadtxt(equil_data_dir + "summary.EKTOT").T
T_x, T_y = np.loadtxt(equil_data_dir + "summary.TEMP").T
P_x, P_y = np.loadtxt(equil_data_dir + "summary.PRES").T

# %%
#plt.plot(T_x, T_y)
plt.plot(P_x[-1000:], P_y[-1000:])
plt.show()
